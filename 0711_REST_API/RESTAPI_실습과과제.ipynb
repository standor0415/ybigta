# %% [markdown]
# # REST API 실습
#
# 22th DE 김원

# %% [markdown]
# ## Python에서

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)
# Out:
# {'page': 2, 'per_page': 6, 'total': 12, 'total_pages': 2, 'data': [{'id': 7, 'email': 'michael.lawson@reqres.in', 'first_name': 'Michael', 'last_name': 'Lawson', 'avatar': 'https://reqres.in/img/faces/7-image.jpg'}, {'id': 8, 'email': 'lindsay.ferguson@reqres.in', 'first_name': 'Lindsay', 'last_name': 'Ferguson', 'avatar': 'https://reqres.in/img/faces/8-image.jpg'}, {'id': 9, 'email': 'tobias.funke@reqres.in', 'first_name': 'Tobias', 'last_name': 'Funke', 'avatar': 'https://reqres.in/img/faces/9-image.jpg'}, {'id': 10, 'email': 'byron.fields@reqres.in', 'first_name': 'Byron', 'last_name': 'Fields', 'avatar': 'https://reqres.in/img/faces/10-image.jpg'}, {'id': 11, 'email': 'george.edwards@reqres.in', 'first_name': 'George', 'last_name': 'Edwards', 'avatar': 'https://reqres.in/img/faces/11-image.jpg'}, {'id': 12, 'email': 'rachel.howell@reqres.in', 'first_name': 'Rachel', 'last_name': 'Howell', 'avatar': 'https://reqres.in/img/faces/12-image.jpg'}], 'support': {'url': 'https://reqres.in/#support-heading', 'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res
# Out:
# {'page': 2,
#  'per_page': 6,
#  'total': 12,
#  'total_pages': 2,
#  'data': [{'id': 7,
#    'email': 'michael.lawson@reqres.in',
#    'first_name': 'Michael',
#    'last_name': 'Lawson',
#    'avatar': 'https://reqres.in/img/faces/7-image.jpg'},
#   {'id': 8,
#    'email': 'lindsay.ferguson@reqres.in',
#    'first_name': 'Lindsay',
#    'last_name': 'Ferguson',
#    'avatar': 'https://reqres.in/img/faces/8-image.jpg'},
#   {'id': 9,
#    'email': 'tobias.funke@reqres.in',
#    'first_name': 'Tobias',
#    'last_name': 'Funke',
#    'avatar': 'https://reqres.in/img/faces/9-image.jpg'},
#   {'id': 10,
#    'email': 'byron.fields@reqres.in',
#    'first_name': 'Byron',
#    'last_name': 'Fields',
#    'avatar': 'https://reqres.in/img/faces/10-image.jpg'},
#   {'id': 11,
#    'email': 'george.edwards@reqres.in',
#    'first_name': 'George',
#    'last_name': 'Edwards',
#    'avatar': 'https://reqres.in/img/faces/11-image.jpg'},
#   {'id': 12,
#    'email': 'rachel.howell@reqres.in',
#    'first_name': 'Rachel',
#    'last_name': 'Howell',
#    'avatar': 'https://reqres.in/img/faces/12-image.jpg'}],
#  'support': {'url': 'https://reqres.in/#support-heading',
#   'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %%
import pandas as pd
df = pd.DataFrame(res['data'])
df
# Out:
#    id                       email first_name last_name  \
# 0   7    michael.lawson@reqres.in    Michael    Lawson
# 1   8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 2   9      tobias.funke@reqres.in     Tobias     Funke
# 3  10      byron.fields@reqres.in      Byron    Fields
# 4  11    george.edwards@reqres.in     George   Edwards
# 5  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1   https://reqres.in/img/faces/8-image.jpg
# 2   https://reqres.in/img/faces/9-image.jpg
# 3  https://reqres.in/img/faces/10-image.jpg
# 4  https://reqres.in/img/faces/11-image.jpg
# 5  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# ## terminal에서

# %% [markdown]
# 가장 간단한 요청입니다 curl + 요청을 보낼 주소 위는 코랩이기 때문에 터미널명령어를 !앞에 붙여 실행합니다 터미널에서는 !안붙여도 괜찮아요!!

# %%
# !curl https://reqres.in/api/users?page=2
# Out:
# {"page":2,"per_page":6,"total":12,"total_pages":2,"data":[{"id":7,"email":"michael.lawson@reqres.in","first_name":"Michael","last_name":"Lawson","avatar":"https://reqres.in/img/faces/7-image.jpg"},{"id":8,"email":"lindsay.ferguson@reqres.in","first_name":"Lindsay","last_name":"Ferguson","avatar":"https://reqres.in/img/faces/8-image.jpg"},{"id":9,"email":"tobias.funke@reqres.in","first_name":"Tobias","last_name":"Funke","avatar":"https://reqres.in/img/faces/9-image.jpg"},{"id":10,"email":"byron.fields@reqres.in","first_name":"Byron","last_name":"Fields","avatar":"https://reqres.in/img/faces/10-image.jpg"},{"id":11,"email":"george.edwards@reqres.in","first_name":"George","last_name":"Edwards","avatar":"https://reqres.in/img/faces/11-image.jpg"},{"id":12,"email":"rachel.howell@reqres.in","first_name":"Rachel","last_name":"Howell","avatar":"https://reqres.in/img/faces/12-image.jpg"}],"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards server costs are appreciated!"}}

# %% [markdown]
# Curl에 여러가지 옵션을 추가할 수 있습니다
#
# -X : HTTP 메서드 지정
# <br>
#
# GET: 리소스를 가져오기 위한 요청입니다. 기본적으로 curl이 사용하는 메서드입니다.<br>
# POST: 리소스를 생성하기 위한 요청입니다. 데이터를 서버로 전송할 때 사용됩니다.<br>
# PUT: 리소스를 수정하기 위한 요청입니다. 전체 리소스를 업데이트합니다.<br>
# PATCH: 리소스를 일부 수정하기 위한 요청입니다. 부분적인 업데이트를 수행할 때 사용됩니다.<br>
# DELETE: 리소스를 삭제하기 위한 요청입니다.
#
# <br>
#
# -H : header 설정 header란 무엇일까? - 범위를 벗어나므로 신원을 확인하거나, 추가적인 정보가 담겨있는 부분: <br> => 메타데이터가 담겨있는 부분입니다!  <br>
#
# -d : data의 약자로 데이터를 넘겨줍니다
#
#
# <br>
#
# 아래의 예시의 경우, 게시판 홈페이지에 사람을 추가하는 예시! <br>
#
# 리소스를 생성하기 때문에 POST method로, 추가해야할 데이터를 -d 인자로 넘겨줍니다

# %%
# !curl -X POST -H "Content-Type: application/json" -d '{"name": "John", "age":30}' https://reqres.in/api/users
# Out:
# {"name":"John","age":30,"id":"384","createdAt":"2023-07-17T10:47:59.116Z"}

# %% [markdown]
# 위 코드를 실행하면, 정상응답이 나오는 경우 reqres.in 페이지에 /api/users에 새로운 유저를 등록 요청하는 request입니다!

# %% [markdown]
# ### 위를 파이썬 버전으로

# %%
import requests
import json

url = 'https://reqres.in/api/users'
headers = {'Content-Type': 'application/json'}
data = {'name': 'John', 'age': 30}


# post method로 요청

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 201: # 상태코드가 201이라면(201 : 요청 정상처리 상태코드 )
    result = response.json()
    print('사용자 생성 완료:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 사용자 생성 완료: {'name': 'John', 'age': 30, 'id': '180', 'createdAt': '2023-07-17T10:48:09.050Z'}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %% [markdown]
# # 페이지를 순회하며 데이터 프레임 만들기! + 약간의 전처리

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)
# Out:
# {'page': 2, 'per_page': 6, 'total': 12, 'total_pages': 2, 'data': [{'id': 7, 'email': 'michael.lawson@reqres.in', 'first_name': 'Michael', 'last_name': 'Lawson', 'avatar': 'https://reqres.in/img/faces/7-image.jpg'}, {'id': 8, 'email': 'lindsay.ferguson@reqres.in', 'first_name': 'Lindsay', 'last_name': 'Ferguson', 'avatar': 'https://reqres.in/img/faces/8-image.jpg'}, {'id': 9, 'email': 'tobias.funke@reqres.in', 'first_name': 'Tobias', 'last_name': 'Funke', 'avatar': 'https://reqres.in/img/faces/9-image.jpg'}, {'id': 10, 'email': 'byron.fields@reqres.in', 'first_name': 'Byron', 'last_name': 'Fields', 'avatar': 'https://reqres.in/img/faces/10-image.jpg'}, {'id': 11, 'email': 'george.edwards@reqres.in', 'first_name': 'George', 'last_name': 'Edwards', 'avatar': 'https://reqres.in/img/faces/11-image.jpg'}, {'id': 12, 'email': 'rachel.howell@reqres.in', 'first_name': 'Rachel', 'last_name': 'Howell', 'avatar': 'https://reqres.in/img/faces/12-image.jpg'}], 'support': {'url': 'https://reqres.in/#support-heading', 'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %% [markdown]
# # 원래 여러분들이 사용하실 때는...
#
# 보통 API의 호출양이 지정되어 있어서, API 세션 아이디, 키가 보통 필요해요!
#
# </br>
#
# 밑에 하고자 했던 코드는 여러페이지에 걸쳐 순회해서 데이터프레임으로 만드는 과정을 보여드리려고했는데,
# 저게 api가 연습용 서버여서 조금 호출 횟수에 제한된 것 같네요!! 원래 1페이지 부터 11페이지까지 6 x 11 행이 나와야하는데, 무료이다보니 서버에 부담이 되어 time.sleep(5)로 해봤는데도 안되네요! 하여튼 예시로 참고하면 좋을 것 같습니다!

# %%
import requests
import pandas as pd
import time

# 빈 데이터프레임 생성
df_combined = pd.DataFrame()

# 페이지 순회
for page in range(1, 11):
    # GET 요청 보내기
    url = f'https://reqres.in/api/users?page={page}'
    response = requests.get(url)

    # 응답 확인
    if response.status_code == 200:
        data = response.json()
        users = data['data']

        # 데이터프레임으로 변환
        df = pd.DataFrame(users)

        # 데이터프레임 결합
        df_combined = pd.concat([df_combined, df], ignore_index=True)
    else:
        print(f'페이지 {page} 요청에 실패했습니다. 상태 코드:', response.status_code)

# 합쳐진 데이터프레임 출력 (아쉽게도 안됨)
df_combined
# Out:
#     id                       email first_name last_name  \
# 0    1      george.bluth@reqres.in     George     Bluth
# 1    2      janet.weaver@reqres.in      Janet    Weaver
# 2    3         emma.wong@reqres.in       Emma      Wong
# 3    4          eve.holt@reqres.in        Eve      Holt
# 4    5    charles.morris@reqres.in    Charles    Morris
# 5    6      tracey.ramos@reqres.in     Tracey     Ramos
# 6    7    michael.lawson@reqres.in    Michael    Lawson
# 7    8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 8    9      tobias.funke@reqres.in     Tobias     Funke
# 9   10      byron.fields@reqres.in      Byron    Fields
# 10  11    george.edwards@reqres.in     George   Edwards
# 11  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                       avatar
# 0    https://reqres.in/img/faces/1-image.jpg
# 1    https://reqres.in/img/faces/2-image.jpg
# 2    https://reqres.in/img/faces/3-image.jpg
# 3    https://reqres.in/img/faces/4-image.jpg
# 4    https://reqres.in/img/faces/5-image.jpg
# 5    https://reqres.in/img/faces/6-image.jpg
# 6    https://reqres.in/img/faces/7-image.jpg
# 7    https://reqres.in/img/faces/8-image.jpg
# 8    https://reqres.in/img/faces/9-image.jpg
# 9   https://reqres.in/img/faces/10-image.jpg
# 10  https://reqres.in/img/faces/11-image.jpg
# 11  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# # 과제 !! 나쁜 사람 아닙니다
#
#
# **개념 요약!! 아래 마크다운을 채워주세요 !! **
#
# 챗지피티 사용금지

# %% [markdown]
# ## API란 ->
# Application Programming Interface의 약자로 프로그램과 Database와 기능들의 상호 통신 방법을 정해주고 도와주는 매개체이다.
#
# ## REST API란 ->
# 자원을 명시하고 HTTP Method를 통해 해당 자원에 대해 CRUD 작동을 적용하는 것
#
# ## 각각에 대응하는 HTTP의 메서드를 적어주세요
#
# ### Create -> POST
# ### Read -> GET
# ### Update -> PUT 또는 PATCH
# ### Delete -> DELETE

# %% [markdown]
# ## 실습 과제 1 공식문서를 읽고 아래의 예시코드에 파라미터를 바꿔서 보낸 결과 확인하기!!
#
# 공식문서에 파라미터들을 직접 넘겨줘서 요청을 보내면 됩니다!

# %% [markdown]
# <https://punkapi.com/documentation/v2>

# %%
# !curl https://api.punkapi.com/v2/beers
# Out:
# [{"id":1,"name":"Buzz","tagline":"A Real Bitter Experience.","first_brewed":"09/2007","description":"A light, crisp and bitter IPA brewed with English and American hops. A small batch brewed only once.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.5,"ibu":60,"target_fg":1010,"target_og":1044,"ebc":20,"srm":10,"ph":4.4,"attenuation_level":75,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":64,"unit":"celsius"},"duration":75}],"fermentation":{"temp":{"value":19,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.3,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Fuggles","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"First Gold","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Fuggles","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"First Gold","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"Cascade","amount":{"value":37.5,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Spicy chicken tikka masala","Grilled chicken quesadilla","Caramel toffee cake"],"brewers_tips":"The earthy and floral aromas from the hops can be overpowering. Drop a little Cascade in at the end of the boil to lift the profile with a bit of citrus.","contributed_by":"Sam Mason <samjbmason>"},{"id":2,"name":"Trashy Blonde","tagline":"You Know You Shouldn't","first_brewed":"04/2008","description":"A titillating, neurotic, peroxide punk of a Pale Ale. Combining attitude, style, substance, and a little bit of low self esteem for good measure; what would your mother say? The seductive lure of the sassy passion fruit hop proves too much to resist. All that is even before we get onto the fact that there are no additives, preservatives, pasteurization or strings attached. All wrapped up with the customary BrewDog bite and imaginative twist.","image_url":"https://images.punkapi.com/v2/2.png","abv":4.1,"ibu":41.5,"target_fg":1010,"target_og":1041.7,"ebc":15,"srm":15,"ph":4.4,"attenuation_level":76,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":69,"unit":"celsius"},"duration":null}],"fermentation":{"temp":{"value":18,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.25,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Amarillo","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Simcoe","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Amarillo","amount":{"value":26.3,"unit":"grams"},"add":"end","attribute":"flavour"},{"name":"Motueka","amount":{"value":18.8,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Fresh crab with lemon","Garlic butter dipping sauce","Goats cheese salad","Creamy lemon bar doused in powdered sugar"],"brewers_tips":"Be careful not to collect too much wort from the mash. Once the sugars are all washed out there are some very unpleasant grainy tasting compounds that can be extracted into the wort.","contributed_by":"Sam Mason <samjbmason>"},{"id":3,"name":"Berliner Weisse With Yuzu - B-Sides","tagline":"Japanese Citrus Berliner Weisse.","first_brewed":"11/2015","description":"Japanese citrus fruit intensifies the sour nature of this German classic.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.2,"ibu":8,"target_fg":1007,"target_og":1040,"ebc":8,"srm":4,"ph":3.2,"attenuation_level":83,"volume":{"value":20,"unit":"litres"},"bo ...

# %% [markdown]
# ```
# response = requests.get('https://reqres.in/api/users?page=2&per_page=10')
# response.get(url,params= {'page': 2, 'per_page':10 })
# ```
#
#
#
# 위에 두개는 같은 요청입니다! 뒤에 파라미터들이 ?으로 , 파라미터가 여러개일 경우 &으로 연결됩니다!

# %%
import requests
import json
import time

url = 'https://api.punkapi.com/v2/beers'
headers = {'Content-Type': 'application/json'}
# 파라미터로 인자 넘겨줄 수 있음!!
# 아래 params 코드에 인자들을 공식문서를 확인하여 추가하시거나 바꿔주세요!!
params= {'page': 3, 'per_page':23, 'abv_gt':6, 'ebc_gt':10}

response = requests.get(url, headers=headers,params=params)

if response.status_code == 200:
    result = response.json()
    print('받아온 데이터:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 받아온 데이터: [{'id': 75, 'name': 'Never Mind The Anabolics', 'tagline': 'Performance-Enhancing India Pale Ale.', 'first_brewed': '06/2012', 'description': 'Never Mind the Anabolics, a 6.5% India Pale Ale brewed with copious amounts of performance-enhancing natural ingredients. Brewed to commemorate the 2012 Olympics and its merry marketing bandwagon.', 'image_url': 'https://images.punkapi.com/v2/75.png', 'abv': 6.5, 'ibu': 35, 'target_fg': 1012, 'target_og': 1050, 'ebc': 23, 'srm': 11.5, 'ph': 4.4, 'attenuation_level': 76, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 68, 'unit': 'celsius'}, 'duration': 30}], 'fermentation': {'temp': {'value': 18, 'unit': 'celsius'}}, 'twist': 'Lycii Berries: 7.5g at end, Ginseng: 5.625g at end, Guarana: 25g at end, Kolabu: 25g at end, Gingko: 6.25g at end, Matcha Tea: 12.5g at end, Maca Powder: 16.25g at end'}, 'ingredients': {'malt': [{'name': 'Extra Pale - Spring Blend', 'amount': {'value': 4.38, 'unit': 'kilograms'}}, {'name': 'Wheat', 'amount': {'value': 0.63, 'unit': 'kilograms'}}, {'name': 'Caramalt', 'amount': {'value': 0.31, 'unit': 'kilograms'}}], 'hops': [{'name': 'Motueka', 'amount': {'value': 37.5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Motueka', 'amount': {'value': 18.75, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 1056 - American Ale™'}, 'food_pairing': ['Grilled chicken salad with bacon and avocado', 'Red pepper houmous and flat bread', 'Matcha green tea cake'], 'brewers_tips': 'Mix the powders into a paste before adding to the wort kettle. This will prevent the powders from balling up and not bringing the full flavour effect.', 'contributed_by': 'Sam Mason <samjbmason>'}, {'id': 76, 'name': '#Mashtag 2013', 'tagline': 'Democratic American Brown Ale.', 'first_brewed': '05/2013', 'description': 'A rich, nutty Brown Ale with a deep, rich malt profile, hopped with a range of citrusy and spicy US varieties. Mellow yet endlessly complex, with enough chocolate and fruit character to balance the bitterness, and a soft oaky roundness.', 'image_url': 'https://images.punkapi.com/v2/76.png', 'abv': 7.5, 'ibu': 50, 'target_fg': 1013, 'target_og': 1070, 'ebc': 40, 'srm': 20, 'ph': 4.4, 'attenuation_level': 81.4, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 65, 'unit': 'celsius'}, 'duration': 90}], 'fermentation': {'temp': {'value': 21, 'unit': 'celsius'}}, 'twist': 'Roasted Hazelnuts: 25g in Tank (FV), Almonds: 12.5g in Tank (FV), Oak Chips: 25g in Tank (FV)'}, 'ingredients': {'malt': [{'name': 'Extra Pale', 'amount': {'value': 5, 'unit': 'kilograms'}}, {'name': 'Dark Crystal', 'amount': {'value': 0.5, 'unit': 'kilograms'}}, {'name': 'Caramalt', 'amount': {'value': 0.44, 'unit': 'kilograms'}}, {'name': 'Amber', 'amount': {'value': 0.25, 'unit': 'kilograms'}}, {'name': 'Chocolate', 'amount': {'value': 0.19, 'unit': 'kilograms'}}], 'hops': [{'name': 'Motueka', 'amount': {'value': 10, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Magnum', 'amount': {'value': 12.5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Cascade', 'amount': {'value': 6, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 6, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Cascade', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}, {'name': 'Willamette', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 1272 - American Ale II™'}, 'food_pairing': ['Roast beef', 'Roasted butternut squash', 'Hazelnut brittle'], 'brewers_tips': 'Add the hazelnuts and oak chips during the cold conditioning phase.', 'contribute ...

# %%
import pandas as pd

df = pd.DataFrame(result)
df
# Out:
#      id                                       name  \
# 0    75                   Never Mind The Anabolics
# 1    76                              #Mashtag 2013
# 2    78                                      AB:18
# 3    79                            Hops Kill Nazis
# 4    80                                      AB:04
# 5    82  Hopped-Up Brown Ale - Prototype Challenge
# 6    83                                      Comet
# 7    86            Original Dogma (Née Speedball)
# 8    88                            Bavarian Weizen
# 9    89                                      Citra
# 10   90                              #Mashtag 2015
# 11   92                                      AB:09
# 12   94                            Everday Anarchy
# 13   96                           Lumberjack Stout
# 14   97                   Bowman's Beard - B-Sides
# 15   99                    Hello My Name Is Päivi
# 16  100     Elvis Juice V2.0 - Prototype Challenge
# 17  101                                    Riptide
# 18  102                              Peach Therapy
# 19  103                                 Clown King
# 20  104       India Pale Weizen (w/ Weihenstephan)
# 21  105                   Hello My Name Is Beastie
# 22  107                      HBC 366 - IPA Is Dead
#
#                                               tagline first_brewed  \
# 0               Performance-Enhancing India Pale Ale.      06/2012
# 1                      Democratic American Brown Ale.      05/2013
# 2               Imperial Brown Ale Aged In Rum Casks.      10/2011
# 3                                   Imperial Red Ale.      08/2011
# 4   Imperial Stout With Coffee, Loads Of Cocoa And...      08/2010
# 5                                   Malt Hop Balance.      01/2016
# 6                           Single Hop India Pale Ale      02/2014
# 7                   Strong Ale With Honey And Spices.      07/2008
# 8                           Unleash the Yeast Series.      09/2013
# 9                       Single Hop IPA Series – 2011.      01/2011
# 10                       US Hopped Black Barley Wine.      05/2015
# 11                          Cranachan Imperial Stout.      11/2010
# 12        White Wine Barrel-Aged Imperial Red Saison.      06/2013
# 13                             Blueberry Bacon Stout.      12/2013
# 14                               English Barley Wine.      03/2015
# 15                          Sea Buckthorn Double IPA.      05/2014
# 16                                Citrus Infused IPA.      12/2015
# 17                           Twisted Merciless Stout.      04/2007
# 18                              Tart Belgian Tripple.      06/2015
# 19                              US Style Barley Wine.      12/2013
# 20                      BrewDog Versus Weihenstephan.      09/2014
# 21                   Double IPA Brewed with Brambles.      08/2012
# 22                         Single Hop India Pale Ale.      02/2014
#
#                                           description  \
# 0   Never Mind the Anabolics, a 6.5% India Pale Al...
# 1   A rich, nutty Brown Ale with a deep, rich malt...
# 2   AB:18 began life as an Imperial Brown Ale befo...
# 3   5AM Saint's big brother. Dry- hopping with Chi...
# 4   Imperial Stout brewed with coffee, cocoa, Naga...
# 5   Brown ales are perfect foils for resinous C-Ho...
# 6   A potently bitter hop variety originally grown...
# 7   A strong ale, brewed with guarana, Californian...
# 8   Our Unleash the Yeast series was an epic exper...
# 9   The Pacific North West of America is home to t...
# 10  Democratically voted on by you and the BrewDog...
# 11  This Cranachan Imperial Stout was inspired by ...
# 12  This French white wine barrel aged Imperial Sa...
# 13  Lumberjack Stout is an intense beast that took...
# 14  Ice-distilled double barley wine brewed by Chr...
# 15  Brewed with sea buckthorn, a tart and bitter b...
# 16  Punchy resinous hoppy aromas blast from the gl...
# 17  The original BrewDog, Bracken decided to make ...
# 18  9% abv sour tripel, infused with peach and apr...
# 19  A heavy hitting combination of rich malt flavo...
# 20   BrewDog vs. Weihenstephan India Pale Weizen k...
# 21  A Scottish take on Hello My Name is Ingrid wit...
# 22  A new, at-the-time un-named American hop now k...
#
#                                 image_url   abv  ibu  target_fg  target_og  \
# 0    https://images.punkapi.com/v2/75.png   6.5   35       1012     1050.0
# 1    https://images.punkapi.com/v2/76.png   7.5   50       1013     1070.0
# 2    https://images.punkapi.com/v2/78.png  11.8   80       1020     1096.0
# 3    https://images.punkapi.com/v2/79.png   7.6   70       1015     1073.0
# 4    https://images.punkapi.com/v2/80.png  15.0   80       1018     1113.0
# 5    https://images.punkapi.com/v2/82.png   6.3   85       1015     1063.0
# 6    https://images.punkapi.com/v2/83.png   7.2   70       1012     1067.0
# 7    https://images.punkapi.com/v2/86.png   7.8   60       1012     1071.3
# 8    https://images.punkapi.com/v2/88.png   6.3   55       1012     1060.0
# 9    https://images.punkapi.com/v2/89.png   7.5   70       1013     1068.0
# 10   https://images.punkapi.com/v2/90.png  10.0   85       1020     1098.0
# 11   https://images.punkapi.com/v2/92.png  11.6   77       1022     1110.0
# 12   https://images.punkapi.com/v2/94.png  10.5   45       1005     1081.0
# 13  https://images.punkapi.com/v2/keg.png  15.2   20       1020     1110.0
# 14  https://images.punkapi.com/v2/keg.png  18.3   50       1011     1067.0
# 15   https://images.punkapi.com/v2/99.png   8.3   70       1013     1076.0
# 16  https://images.punkapi.com/v2/100.png   6.5   60       1010     1060.0
# 17  https://images.punkapi.com/v2/101.png   8.0   45       1014     1075.0
# 18  https://images.punkapi.com/v2/keg.png   9.0   30       1000     1071.0
# 19  https://images.punkapi.com/v2/103.png  12.0   85       1020     1130.0
# 20  https://images.punkapi.com/v2/104.png   6.2   50       1010     1056.0
# 21  https://images.punkapi.com/v2/105.png   8.2   42       1013     1078.0
# 22  https://images.punkapi.com/v2/107.png   7.2   70       1012     1067.0
#
#     ...    srm   ph  attenuation_level                           volume  \
# 0   ...   11.5  4.4               76.0  {'value': 20, 'unit': 'litres'}
# 1   ...   20.0  4.4               81.4  {'value': 20, 'unit': 'litres'}
# 2   ...   57.5  5.2               79.2  {'value': 20, 'unit': 'litres'}
# 3   ...   29.5  4.4               79.5  {'value': 20, 'unit': 'litres'}
# 4   ...  200.0  4.0               84.1  {'value': 20, 'unit': 'litres'}
# 5   ...   12.0  4.2               82.6  {'value': 20, 'unit': 'litres'}
# 6   ...   15.0  4.4               82.1  {'value': 20, 'unit': 'litres'}
# 7   ...   15.5  4.3               83.2  {'value': 20, 'unit': 'litres'}
# 8   ...   15.0  4.4               80.0  {'value': 20, 'unit': 'litres'}
# 9   ...   15.0  4.4               82.1  {'value': 20, 'unit': 'litres'}
# 10  ...   65.0  4.4               79.6  {'value': 20, 'unit': 'litres'}
# 11  ...  132.5  5.2               80.0  {'value': 20, 'unit': 'litres'}
# 12  ...    7.5  4.4               93.8  {'value': 20, 'unit': 'litres'}
# 13  ...   79.0  4.4               82.0  {'value': 20, 'unit': 'litres'}
# 14  ...    8.0  5.3               84.0  {'value': 20, 'unit': 'litres'}
# 15  ...   15.0  4.4               82.9  {'value': 20, 'unit': 'litres'}
# 16  ...   12.5  4.4               83.3  {'value': 20, 'unit': 'litres'}
# 17  ...  120.0  4.4               81.3  {'value': 20, 'unit': 'litres'}
# 18  ...    6.0  3.6               87.0  {'value': 20, 'unit': 'litres'}
# 19  ...   12.0  4.4              102.3  {'value': 20, 'unit': 'litres'}
# 20  ...   17.5  4.0               85.0  {'value': 20, 'unit': 'litres'}
# 21  ...   45.0  4.4               83.3  {'value': 20, 'unit': 'litres'}
# 22  ...   15.0  4.4               82.1  {'value': 20, 'unit': 'litres'}
#
#                         boil_volume  \
# 0   {'value': 25, 'unit': 'litres'}
# 1   {'value': 25, 'unit': 'litres'}
# 2   {'value': 25, 'unit': 'litres'}
# 3   {'value': 25, 'unit': 'litres'}
# 4   {'value': 25, 'unit': 'litres'}
# 5   {'value': 25, 'unit': 'litres'}
# 6   {'value': 25, 'unit': 'litres'}
# 7   {'value': 25, 'unit': 'litres'}
# 8   {'value': 25, 'unit': 'litres'}
# 9   {'value': 25, 'unit': 'litres'}
# 10  {'value': 25, 'unit': 'litres'}
# 11  {'value': 25, 'unit': 'litres'}
# 12  {'value': 25, 'unit': 'litres'}
# 13  {'value': 25, 'unit': 'litres'}
# 14  {'value': 25, 'unit': 'litres'}
# 15  {'value': 25, 'unit': 'litres'}
# 16  {'value': 25, 'unit': 'litres'}
# 17  {'value': 25, 'unit': 'litres'}
# 18  {'value': 25, 'unit': 'litres'}
# 19  {'value': 25, 'unit': 'litres'}
# 20  {'value': 25, 'unit': 'litres'}
# 21  {'value': 25, 'unit': 'litres'}
# 22  {'value': 25, 'unit': 'litres'}
#
#                                                method  \
# 0   {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 1   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2   {'mash_temp': [{'temp': {'value': 69, 'unit': ...
# 3   {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 4   {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 5   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 6   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 7   {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 8   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 9   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 10  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 11  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 12  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 13  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 14  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 15  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 16  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 17  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 18  {'mash_temp': [{'temp': {'value': 60, 'unit': ...
# 19  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 20  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 21  {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 22  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
#
#                                           ingredients  \
# 0   {'malt': [{'name': 'Extra Pale - Spring Blend'...
# 1   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 2   {'malt': [{'name': 'Extra Pale - Spring Blend'...
# 3   {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 4   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 5   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 6   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 7   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 8   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 9   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 10  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 11  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 12  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 13  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 14  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 15  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 16  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 17  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 18  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 19  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 20  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 21  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 22  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
#
#                                          food_pairing  \
# 0   [Grilled chicken salad with bacon and avocado,...
# 1   [Roast beef, Roasted butternut squash, Hazelnu...
# 2   [Kippers and poached eggs, Slow cooked lamb sh...
# 3   [Candied almond and blue cheese rocket salad, ...
# 4   [Beef mahaca on corn tortillas, Chilli and dar...
# 5   [Butternut squash and sage soup, Roast beef an...
# 6   [Margherita pizza with chili flakes, Spicy Tha...
# 7   [Spicy seafood stew, French onion soup, Mexica...
# 8   [Spicy paella, German bratwurst with spicy mus...
# 9   [Lemon and herb salmon, Sharp cheddar with man...
# 10  [Charcuterie platter (featuring Italian salami...
# 11  [Aged cheddar with honey and raspberry chutney...
# 12  [Spiced carrot and coriander soup, Spicy chill...
# 13  [Maple syrup drizzled chocolate chip pancakes,...
# 14  [Celery and stilton soup, Salted caramel souff...
# 15  [Korvapuusti (cinnamon and cardamom buns), Spi...
# 16  [Mexican ceviche, Coriander and lime green tha...
# 17  [Seared scallops, Pan seared venison with frui...
# 18  [Summer salad with pickled veg, Sticky barbecu...
# 19  [Aged Stilton, Flaky pastry beef pie and sweet...
# 20  [Korean barbecue nachos, Beef pho soup, Waffle...
# 21  [Honey glazed ham with pineapple, Spicy wings ...
# 22  [Spicy black bean and chicken tortilla soup, S...
#
#                                          brewers_tips  \
# 0   Mix the powders into a paste before adding to ...
# 1   Add the hazelnuts and oak chips during the col...
# 2   Blend aged beer with a fresh brewed black ale ...
# 3   A red colour is a difficult hue to achieve in ...
# 4   Make sure you can get the coffee, cocoa and ch...
# 5   High carbonate water will really accent the ma...
# 6   Experiment with other high alpha hops during d...
# 7   Get really good quality heather honey, the mor...
# 8   Play around with the fermentation temperature ...
# 9   Another hop to be treated with respect. Too mu...
# 10  Steep the oak chips and vanilla in separate ba...
# 11  Lactose - or milk sugar - is un-fermentable. I...
# 12  The honey addition will help to dry out the be...
# 13  Adding extra smoked malt will amp up the bacon...
# 14  Ferment first with the American ale strain and...
# 15  Sea buckthorn characteristics can vary from it...
# 16  Shave of the surface of the citrus peel to unl...
# 17  We recommend adding the chocolate malt at the ...
# 18  20% of the original volume of wort was brewed ...
# 19  Leave this beer to chill in the cellar for a f...
# 20  Let the fermentation temperature creep up a co...
# 21  For easy addition, freeze the berries and then...
# 22  With new hop varieties, growers are discoverin...
#
#               contributed_by
# 0     Sam Mason <samjbmason>
# 1     Sam Mason <samjbmason>
# 2     Sam Mason <samjbmason>
# 3     Sam Mason <samjbmason>
# 4     Sam Mason <samjbmason>
# 5     Sam Mason <samjbmason>
# 6   Ali Skinner <AliSkinner>
# 7     Sam Mason <samjbmason>
# 8   Ali Skinner <AliSkinner>
# 9     Sam Mason <samjbmason>
# 10    Sam Mason <samjbmason>
# 11    Sam Mason <samjbmason>
# 12    Sam Mason <samjbmason>
# 13  Ali Skinner <AliSkinner>
# 14    Sam Mason <samjbmason>
# 15    Sam Mason <samjbmason>
# 16    Sam Mason <samjbmason>
# 17    Sam Mason <samjbmason>
# 18    Sam Mason <samjbmason>
# 19  Ali Skinner <AliSkinner>
# 20    Sam Mason <samjbmason>
# 21    Sam Mason <samjbmason>
# 22    Sam Mason <samjbmason>
#
# [23 rows x 21 columns]

# %% [markdown]
# ## 과제 2 컨퍼런스 혹은 신입기수 세션에서 데이터를 끌어올 수 있는 API를 찾아보시고 찾기!
#
#
#
# - response 응답의 구조를 파악하여 어떤 열을 어떻게 활용할 수 있을지 적어보세요!
#
# - 찾은 API 명세서 -> 활용방안을 적어주시면 됩니다!

# %% [markdown]
# 추천 :
#
# 요즘은 다른 거를 가져다가 쓰는 게 또 능력이죠
#
# ### <https://www.reddit.com/dev/api/>
#
# ### <https://developers.kakao.com/>
#
# ### <https://developers.naver.com/main/>
#
# ### <https://platform.openai.com/docs/introduction>

# %% [markdown]
# # 아래 작성해주시면 됩니다!!

# %% [markdown]
# ### 사용할 API :
# Naver api 검색
#
# ### 사용할 기능또는 api 응답에서 제공되는 변수 :
# 검색을 통해 관련된 책 찾기
# 변수: 책 제목, 네이버 도서 정보 URL, 섬네일 이미지의  URL, 저자 이름, 판매 가격, 출판사, 출간일 등
# ### 활용 방안 :
# 특정 단어가 들어간 책의 이미지를 URL를 통해 모을 수 있다. 책 제목을 통해 책 표지 만드는 생성 AI를 만들 때 데이터로 사용할 수 있다.

# %% [markdown]
# # 출처
#
# - 내머리
# - 챗지피티
